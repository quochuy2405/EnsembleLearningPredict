# %% [markdown]
# # 1. Quá trình dự báo trên mô hình LR

# %% [markdown]
# ## Thêm thư viện

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from statsmodels.tsa.stattools import adfuller
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error
# from sklearn.utils import column_or_1d
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import load_model
import optuna

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import StackingRegressor

# %%
study = optuna.create_study()
# Out:
# [I 2022-12-04 21:38:40,732] A new study created in memory with name: no-name-43060efd-ca5a-4652-9023-3803bc4d7aa2

# %%
# Load data
df = pd.read_csv('../../data/btc.csv')
print(df)
name_col='low'
# Out:
#      formatted_date          high           low          open         close  \
# 0        2019-01-01   3850.913818   3707.231201   3746.713379   3843.520020
# 1        2019-01-02   3947.981201   3817.409424   3849.216309   3943.409424
# 2        2019-01-03   3935.685059   3826.222900   3931.048584   3836.741211
# 3        2019-01-04   3865.934570   3783.853760   3832.040039   3857.717529
# 4        2019-01-05   3904.903076   3836.900146   3851.973877   3845.194580
# ...             ...           ...           ...           ...           ...
# 1420     2022-11-22  16253.047852  15656.606445  15782.300781  16189.769531
# 1421     2022-11-23  16638.193359  16170.502930  16195.588867  16610.707031
# 1422     2022-11-24  16771.474609  16501.767578  16611.636719  16604.464844
# 1423     2022-11-25  16603.316406  16388.404297  16602.269531  16521.841797
# 1424     2022-11-26  16666.863281  16521.164062  16524.724609  16620.326172
#
#            volume      adjclose
# 0      4324200990   3843.520020
# 1      5244856836   3943.409424
# 2      4530215219   3836.741211
# 3      4847965467   3857.717529
# 4      5137609824   3845.194580
# ...           ...           ...
# 1420  30726828760  16189.769531
# 1421  32958875628  16610.707031
# 1422  26129037414  16604.464844
# 1423  18678255976  16521.841797
# 1424  18700961792  16620.326172
#
# [1425 rows x 7 columns]

# %%
# Process data
df['H-L'] = df['high'] - df['low']
df['O-C'] = df['open'] - df['close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
df[f'SMA_{ma_1}'] = df[name_col].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df[name_col].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df[name_col].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df[name_col].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df[name_col].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv(f"../../predict/bitcoin_df_{name_col}.csv")
df.set_index('formatted_date')
# Out:
#                         high           low          open         close  \
# formatted_date
# 2019-01-21       3608.840820   3558.537109   3600.372803   3576.032471
# 2019-01-22       3620.746582   3539.721436   3575.081299   3604.577148
# 2019-01-23       3623.067871   3565.313965   3605.557129   3585.123047
# 2019-01-24       3616.087402   3569.092773   3584.500244   3600.865479
# 2019-01-25       3612.927734   3575.597412   3607.390381   3599.765869
# ...                      ...           ...           ...           ...
# 2022-11-22      16253.047852  15656.606445  15782.300781  16189.769531
# 2022-11-23      16638.193359  16170.502930  16195.588867  16610.707031
# 2022-11-24      16771.474609  16501.767578  16611.636719  16604.464844
# 2022-11-25      16603.316406  16388.404297  16602.269531  16521.841797
# 2022-11-26      16666.863281  16521.164062  16524.724609  16620.326172
#
#                      volume      adjclose         H-L         O-C  \
# formatted_date
# 2019-01-21       5004347059   3576.032471   50.303711   24.340332
# 2019-01-22       5313623556   3604.577148   81.025146  -29.495850
# 2019-01-23       5433755649   3585.123047   57.753906   20.434082
# 2019-01-24       5262869046   3600.865479   46.994629  -16.365234
# 2019-01-25       5265847539   3599.765869   37.330322    7.624512
# ...                     ...           ...         ...         ...
# 2022-11-22      30726828760  16189.769531  596.441406 -407.468750
# 2022-11-23      32958875628  16610.707031  467.690430 -415.118164
# 2022-11-24      26129037414  16604.464844  269.707031    7.171875
# 2022-11-25      18678255976  16521.841797  214.912109   80.427734
# 2022-11-26      18700961792  16620.326172  145.699219  -95.601562
#
#                        SMA_7        SMA_14        SMA_21        SD_7  \
# formatted_date
# 2019-01-21       3613.942697   3670.034616   3723.786156   32.285647
# 2019-01-22       3602.481585   3637.375052   3715.809501   42.440931
# 2019-01-23       3594.001674   3604.707275   3703.804955   43.191418
# 2019-01-24       3586.449079   3598.272862   3691.560663   42.095987
# 2019-01-25       3577.665737   3592.739118   3681.643694   35.699181
# ...                      ...           ...           ...         ...
# 2022-11-22      16218.594587  16212.732701  17497.666481  417.816570
# 2022-11-23      16181.507673  16247.576311  17311.160203  407.302000
# 2022-11-24      16187.376814  16295.272670  17140.471029  412.261163
# 2022-11-25      16162.204381  16284.195661  16959.536970  390.176501
# 2022-11-26      16155.169224  16274.866281  16741.609794  381.946736
#
#                       SD_21
# formatted_date
# 2019-01-21       152.462873
# 2019-01-22       157.665491
# 2019-01-23       159.133311
# 2019-01-24       159.135328
# 2019-01-25       159.584655
# ...                     ...
# 2022-11-22      1992.579342
# 2022-11-23      1920.064964
# 2022-11-24      1817.624905
# 2022-11-25      1683.237633
# 2022-11-26      1391.703250
#
# [1405 rows x 13 columns]

# %% [markdown]
# ## Nạp dữ liệu từ file csv

# %%
df2 = pd.read_csv(f"../../predict/bitcoin_df_{name_col}.csv", parse_dates=True)
for i in range(0,len(df2)-1) :
    df2[name_col][i]=df2[name_col][i+1]

split_x = df2[['high','open','close','H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}','formatted_date']]
split_y = df2[[name_col]]

X_train, X_val,y_train, y_val = train_test_split(split_x,split_y ,
                                   random_state=104, 
                                   test_size=0.2, 
                                   shuffle=True)

# %% [markdown]
# ## Chuẩn hóa dữ liệu

# %%
cols_x = ['high','open','close','H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = [name_col]
x_train = X_train[cols_x].values.reshape(-1, len(cols_x))
y_train = y_train[cols_y].values.reshape(-1, len(cols_y))
print(x_train.shape, y_train.shape)
# Out:
# (1124, 10) (1124, 1)

# %%
x_test = X_val[cols_x].values.reshape(-1, len(cols_x))
y_test = y_val[cols_y].values.reshape(-1, len(cols_y))
print(x_test.shape, y_test.shape)
# Out:
# (281, 10) (281, 1)

# %% [markdown]
# # 2. Quá trình dự đoán trên mô hình

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import GradientBoostingRegressor

# %%
_gdm = ('gradientboosting', GradientBoostingRegressor(learning_rate= 0.07, max_depth= 8, n_estimators= 1000, subsample= 0.3));
_elm = ('elasticnet', ElasticNet(alpha= 0.01, l1_ratio= 0.8, positive= True, random_state= 100, selection= 'random', tol= 0.2, warm_start= True));
_lsm = ('lasso', Lasso(alpha= 3.17, copy_X= True, fit_intercept= False, max_iter= 1, normalize= True, positive= False, precompute= False, random_state= None, selection= 'random', tol= 0.3, warm_start= False));
_ridge = ('ridge',Ridge(alpha= 0.0006, copy_X= True, fit_intercept= False, max_iter= 1, normalize= False, positive= True, random_state= None, solver= 'auto', tol= 0.001));
_lr = ('linear',LinearRegression())

# %%
from itertools import permutations 
perm = permutations([_lr, _gdm, _lsm, _ridge]) 
_estimator_elm = []
for i in list(perm): 
    _estimator_elm.append(i)

# %%
parameters = {'estimators':_estimator_elm,  
              'final_estimator':_elm}
elm_grid = GridSearchCV(StackingRegressor(estimators= None, final_estimator = None),parameters, scoring='r2', cv=None).fit(x_train, y_train.reshape(-1, len(cols_y)))
print(elm_grid.best_params_)
elm_reg = StackingRegressor(estimators= elm_grid.best_params_["estimators"], final_estimator = elm_grid.best_params_["final_estimator"])
elm_reg.fit(x_train, y_train.reshape(-1, 1))
# Out:
# {'estimators': (('lasso', Lasso(alpha=3.17, fit_intercept=False, max_iter=1, normalize=True,
#       selection='random', tol=0.3)), ('ridge', Ridge(alpha=0.0006, fit_intercept=False, max_iter=1, normalize=False,
#       positive=True)), ('linear', LinearRegression()), ('gradientboosting', GradientBoostingRegressor(learning_rate=0.07, max_depth=8, n_estimators=1000,
#                           subsample=0.3))), 'final_estimator': ElasticNet(alpha=0.01, l1_ratio=0.8, positive=True, random_state=100,
#            selection='random', tol=0.2, warm_start=True)}
# StackingRegressor(estimators=(('lasso',
#                                Lasso(alpha=3.17, fit_intercept=False,
#                                      max_iter=1, normalize=True,
#                                      selection='random', tol=0.3)),
#                               ('ridge',
#                                Ridge(alpha=0.0006, fit_intercept=False,
#                                      max_iter=1, normalize=False,
#                                      positive=True)),
#                               ('linear', LinearRegression()),
#                               ('gradientboosting',
#                                GradientBoostingRegressor(learning_rate=0.07,
#                                                          max_depth=8,
#                                                          n_estimators=1000,
#                                                          subsample=0.3))),
#                   final_estimator=ElasticNet(alpha=0.01, l1_ratio=0.8,
#                                              positive=True, random_state=100,
#                                              selection='random', tol=0.2,
#                                              warm_start=True))

# %%
elm_reg.save("stacking_low.h5")
elm_pred = elm_reg.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\19521\OneDrive\Máy tính\KLTN\LSTM-all-variables\train\Stacking\stacking_low.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/19521/OneDrive/M%C3%A1y%20t%C3%ADnh/KLTN/LSTM-all-variables/train/Stacking/stacking_low.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> elm_reg.save("stacking_low.h5")
#       <a href='vscode-notebook-cell:/c%3A/Users/19521/OneDrive/M%C3%A1y%20t%C3%ADnh/KLTN/LSTM-all-variables/train/Stacking/stacking_low.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> elm_pred = elm_reg.predict(x_test)
#
# AttributeError: 'StackingRegressor' object has no attribute 'save'

# %%
plt.figure(figsize=(16, 9))
plt.grid(True)
plt.ylabel('Closing Prices')
plt.plot(y_test, 'blue', label='Actual data')
plt.plot(elm_pred, 'cyan', label='Staking ElasticNet predicted data')
plt.legend()
X_test['predict']=elm_pred
X_test.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\19521\OneDrive\Máy tính\KLTN\LSTM-all-variables\train\Stacking\stacking_low.ipynb Cell 19 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/19521/OneDrive/M%C3%A1y%20t%C3%ADnh/KLTN/LSTM-all-variables/train/Stacking/stacking_low.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(elm_pred, 'cyan', label='Staking ElasticNet predicted data')
#       <a href='vscode-notebook-cell:/c%3A/Users/19521/OneDrive/M%C3%A1y%20t%C3%ADnh/KLTN/LSTM-all-variables/train/Stacking/stacking_low.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a> plt.legend()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/19521/OneDrive/M%C3%A1y%20t%C3%ADnh/KLTN/LSTM-all-variables/train/Stacking/stacking_low.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a> X_test['predict']=elm_pred
#       <a href='vscode-notebook-cell:/c%3A/Users/19521/OneDrive/M%C3%A1y%20t%C3%ADnh/KLTN/LSTM-all-variables/train/Stacking/stacking_low.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> X_test.tail()
#
# NameError: name 'X_test' is not defined

# %%
import pickle

# %%
filename = f'../../model/stacking/stacking_{name_col}.h5'
pickle.dump(elm_reg, open(filename, 'wb'))
