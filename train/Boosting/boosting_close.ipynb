# %%
import pandas as pd
import datetime as dt
import numpy as np

from csv import writer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU
from keras.models import load_model

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/btc.csv')
print(df)
# Out:
#      formatted_date          high           low          open         close  \
# 0        2014-09-17    468.174011    452.421997    465.864014    457.334015
# 1        2014-09-18    456.859985    413.104004    456.859985    424.440002
# 2        2014-09-19    427.834991    384.532013    424.102997    394.795990
# 3        2014-09-20    423.295990    389.882996    394.673004    408.903992
# 4        2014-09-21    412.425995    393.181000    408.084991    398.821014
# ...             ...           ...           ...           ...           ...
# 3017     2022-12-21  16916.800781  16755.912109  16904.527344  16817.535156
# 3018     2022-12-22  16866.673828  16592.408203  16818.380859  16830.341797
# 3019     2022-12-23  16905.218750  16794.458984  16829.644531  16796.953125
# 3020     2022-12-24  16864.703125  16793.527344  16796.976562  16847.755859
# 3021     2022-12-25  16859.472656  16824.105469  16847.066406  16830.982422
#
#            volume      adjclose
# 0        21056800    457.334015
# 1        34483200    424.440002
# 2        37919700    394.795990
# 3        36863600    408.903992
# 4        26580100    398.821014
# ...           ...           ...
# 3017  14882945045  16817.535156
# 3018  16441573050  16830.341797
# 3019  15329265213  16796.953125
# 3020   9744636213  16847.755859
# 3021   9435307008  16830.982422
#
# [3022 rows x 7 columns]

# %%
# Process data
df['H-L'] = df['high'] - df['low']
df['O-C'] = df['open'] - df['close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
df[f'SMA_{ma_1}'] = df['close'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['close'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['close'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['close'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['close'].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv("../../data/BOOSTING/bitcoin_processed_close.csv")
df
# Out:
#      formatted_date          high           low          open         close  \
# 20       2014-10-07    339.247009    320.481995    330.584015    336.187012
# 21       2014-10-08    354.364014    327.187988    336.115997    352.940002
# 22       2014-10-09    382.726013    347.687012    352.747986    365.026001
# 23       2014-10-10    375.066986    352.963013    364.687012    361.562012
# 24       2014-10-11    367.191010    355.950989    361.362000    362.299011
# ...             ...           ...           ...           ...           ...
# 3017     2022-12-21  16916.800781  16755.912109  16904.527344  16817.535156
# 3018     2022-12-22  16866.673828  16592.408203  16818.380859  16830.341797
# 3019     2022-12-23  16905.218750  16794.458984  16829.644531  16796.953125
# 3020     2022-12-24  16864.703125  16793.527344  16796.976562  16847.755859
# 3021     2022-12-25  16859.472656  16824.105469  16847.066406  16830.982422
#
#            volume      adjclose         H-L        O-C         SMA_7  \
# 20       49199900    336.187012   18.765015  -5.602997    347.691572
# 21       54736300    352.940002   27.176025 -16.824005    343.309431
# 22       83641104    365.026001   35.039001 -12.278015    341.874289
# 23       43665700    361.562012   22.103973   3.125000    342.167149
# 24       13345200    362.299011   11.240021  -0.937012    346.943294
# ...           ...           ...         ...        ...           ...
# 3017  14882945045  16817.535156  160.888672  86.992188  16818.419643
# 3018  16441573050  16830.341797  274.265625 -11.960938  16742.059152
# 3019  15329265213  16796.953125  110.759766  32.691406  16763.411830
# 3020   9744636213  16847.755859   71.175781 -50.779297  16770.935268
# 3021   9435307008  16830.982422   35.367188  16.083984  16781.364676
#
#             SMA_14        SMA_21        SD_7       SD_21
# 20      372.296927    387.352142   24.885399   36.587375
# 21      367.278000    382.380999   19.656765   33.571190
# 22      363.953142    379.551761   17.159362   32.330045
# 23      360.891501    377.969190   17.524172   32.359917
# 24      358.232860    375.749906   17.847829   31.724161
# ...            ...           ...         ...         ...
# 3017  17080.849191  17054.231492  283.780350  326.829495
# 3018  17052.053990  17047.717634  154.871238  329.999982
# 3019  17028.039760  17033.826823  149.882179  334.301829
# 3020  17007.970564  17030.946801  153.026188  335.695510
# 3021  16988.455497  17016.684710  154.476756  337.611877
#
# [3002 rows x 14 columns]

# %%
pre_day = 30
scala_x = MinMaxScaler(feature_range=(0,1))
scala_y = MinMaxScaler(feature_range=(0,1))
cols_x = ['high','low','open','H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['close']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))

x_total = []
y_total = []

for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])

# test_size = (int)(len(scaled_data_y) * 0.2)
# print(test_size)

x_train = np.array(x_total[:len(x_total)])
# x_test = np.array(x_total[len(x_total)-test_size:])
y_train = np.array(y_total[:len(y_total)])
# y_test = np.array(y_total[len(y_total)-test_size:])



# print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# %%
# Build model
model = Sequential()

model.add(GRU(units=60, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=120, steps_per_epoch=40, use_multiprocessing=True)
model.save("../../model/BOOSTING/GRU_boosting_close.h5")
# Out:
# Epoch 1/120
# 40/40 [==============================] - 11s 54ms/step - loss: 0.0110
# Epoch 2/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0028
# Epoch 3/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0025
# Epoch 4/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0019
# Epoch 5/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0018
# Epoch 6/120
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0017
# Epoch 7/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0016
# Epoch 8/120
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0016
# Epoch 9/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0013
# Epoch 10/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0014
# Epoch 11/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0017
# Epoch 12/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0013
# Epoch 13/120
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0018
# Epoch 14/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0016
# Epoch 15/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0014
# Epoch 16/120
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0014
# Epoch 17/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0012
# Epoch 18/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0011
# Epoch 19/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0013
# Epoch 20/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0012
# Epoch 21/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0011
# Epoch 22/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0014
# Epoch 23/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0013
# Epoch 24/120
# 40/40 [==============================] - 2s 58ms/step - loss: 9.7555e-04
# Epoch 25/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0010
# Epoch 26/120
# 40/40 [==============================] - 2s 57ms/step - loss: 9.9334e-04
# Epoch 27/120
# 40/40 [==============================] - 2s 55ms/step - loss: 9.6400e-04
# Epoch 28/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0010
# Epoch 29/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0010
# Epoch 30/120
# 40/40 [==============================] - 2s 55ms/step - loss: 9.4099e-04
# Epoch 31/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0010
# Epoch 32/120
# 40/40 [==============================] - 2s 57ms/step - loss: 9.0870e-04
# Epoch 33/120
# 40/40 [==============================] - 2s 59ms/step - loss: 9.8504e-04
# Epoch 34/120
# 40/40 [==============================] - 2s 56ms/step - loss: 8.7422e-04
# Epoch 35/120
# 40/40 [==============================] - 2s 57ms/step - loss: 8.2372e-04
# Epoch 36/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0011
# Epoch 37/120
# 40/40 [==============================] - 2s 55ms/step - loss: 8.4052e-04
# Epoch 38/120
# 40/40 [==============================] - 2s 57ms/step - loss: 8.9072e-04
# Epoch 39/120
# 40/40 [==============================] - 2s 55ms/step - loss: 7.8485e-04
# Epoch 40/120
# 40/40 [==============================] - 2s 58ms/step - loss: 7.1610e-04
# Epoch 41/120
# 40/40 [==============================] - 2s 55ms/step - loss: 9.0695e-04
# Epoch 42/120
# 40/40 [==============================] - 2s 56ms/step - loss: 7.7651e-04
# Epoch 43/120
# 40/40 [==============================] - 2s 56ms/step - loss: 7.9994e-04
# Epoch 44/120
# 40/40 [==============================] - 2s 55ms/step - loss: 7.8372e-04
# Epoch 45/120
# 40/40 [==============================] - 2s 57ms/step - loss: 8.4151e-04
# Epoch 46/120
# 40/40 [==============================] - 2s 56ms/step - loss: 8.5197e-04
# Epoch 47/120
# 40/40 [==============================] - 2s 61ms/step - loss: 7.4495e-04
# Epoch 48/120
# 40/40 [==============================] - 2s 58ms/step - loss: 6.7784e-04
# Epoch 49/120
# 40/40 [==============================] - 2s 58ms/step - loss: 8.7797e-04
# Epoch 50/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0011
# Epoch 51/120
# 40/40 [==============================] - 2s 55ms/step - loss: 7.6195e-04
# Epoch 52/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0011
# Epoch 53/120
# 40/40 [==============================] - 2s 55ms/step - loss: 7.3153e-04
# Epoch 54/120
# 40/40 [==============================] - 2s 57ms/step - loss: 7.4845e-04
# Epoch 55/120
# 40/40 [==============================] - 2s 55ms/step - loss: 7.5972e-04
# Epoch 56/120
# 40/40 [==============================] - 2s 57ms/step - loss: 7.4570e-04
# Epoch 57/120
# 40/40 [==============================] - 2s 57ms/step - loss: 8.3058e-04
# Epoch 58/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0011
# Epoch 59/120
# 40/40 [==============================] - 2s 57ms/step - loss: 8.2335e-04
# Epoch 60/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0011
# Epoch 61/120
# 40/40 [==============================] - 2s 61ms/step - loss: 7.5971e-04
# Epoch 62/120
# 40/40 [==============================] - 2s 58ms/step - loss: 7.5654e-04
# Epoch 63/120
# 40/40 [==============================] - 2s 57ms/step - loss: 9.2493e-04
# Epoch 64/120
# 40/40 [==============================] - 2s 56ms/step - loss: 7.8206e-04
# Epoch 65/120
# 40/40 [==============================] - 2s 55ms/step - loss: 7.2264e-04
# Epoch 66/120
# 40/40 [==============================] - 2s 57ms/step - loss: 6.9076e-04
# Epoch 67/120
# 40/40 [==============================] - 2s 55ms/step - loss: 6.0249e-04
# Epoch 68/120
# 40/40 [==============================] - 2s 57ms/step - loss: 7.1929e-04
# Epoch 69/120
# 40/40 [==============================] - 2s 55ms/step - loss: 6.4212e-04
# Epoch 107/120
# 40/40 [==============================] - 2s 56ms/step - loss: 5.6993e-04
# Epoch 108/120
# 40/40 [==============================] - 2s 57ms/step - loss: 6.0811e-04
# Epoch 109/120
# 40/40 [==============================] - 2s 56ms/step - loss: 7.2156e-04
# Epoch 110/120
# 40/40 [==============================] - 2s 58ms/step - loss: 5.3948e-04
# Epoch 111/120
# 40/40 [==============================] - 2s 55ms/step - loss: 5.8633e-04
# Epoch 112/120
# 40/40 [==============================] - 2s 58ms/step - loss: 6.6095e-04
# Epoch 113/120
# 40/40 [==============================] - 2s 55ms/step - loss: 8.3290e-04
# Epoch 114/120
# 40/40 [==============================] - 2s 56ms/step - loss: 6.5717e-04
# Epoch 115/120
# 40/40 [==============================] - 2s 58ms/step - loss: 6.2647e-04
# Epoch 116/120
# 40/40 [==============================] - 2s 56ms/step - loss: 6.8967e-04
# Epoch 117/120
# 40/40 [==============================] - 2s 58ms/step - loss: 6.0978e-04
# Epoch 118/120
# 40/40 [==============================] - 2s 60ms/step - loss: 6.5630e-04
# Epoch 119/120
# 40/40 [==============================] - 2s 60ms/step - loss: 5.5771e-04
# Epoch 120/120
# 40/40 [==============================] - 3s 76ms/step - loss: 6.2076e-04

# %%
# Testing
predict_price = model.predict(x_train)
predict_price = scala_y.inverse_transform(predict_price)
y_train_price = scala_y.inverse_transform(y_train)

error = pd.concat([pd.DataFrame(predict_price,columns=['predict_price'],index=None), pd.DataFrame(y_train_price,columns=['y_train_price'],index=None)], axis=1)
error['error_price'] = error['predict_price'] - error['y_train_price']
print(error)
# Out:
# 93/93 [==============================] - 4s 14ms/step
#       predict_price  y_train_price  error_price
# 0        389.486847     349.290009    40.196838
# 1        400.238495     342.415009    57.823486
# 2        397.060303     345.488007    51.572296
# 3        396.851440     363.264008    33.587433
# 4        410.754181     366.924011    43.830170
# ...             ...            ...          ...
# 2967   16680.507812   16817.535156  -137.027344
# 2968   16687.789062   16830.341797  -142.552734
# 2969   16682.265625   16796.953125  -114.687500
# 2970   16700.488281   16847.755859  -147.267578
# 2971   16758.636719   16830.982422   -72.345703
#
# [2972 rows x 3 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
import pickle
gradient =  GradientBoostingRegressor(learning_rate= 0.07, max_depth= 8, n_estimators= 1000, subsample= 0.3)

# %%
gradient.fit(error['predict_price'].values.reshape(-1, 1), error['error_price'].values)
pickle.dump(gradient, open("../../model/BOOSTING/booting_gradient_close.h5", "wb"))

# %%
gradient.predict(np.array([50762.023438]).reshape(-1,1))
# Out:
# array([3445.31685057])

# %% [markdown]
# TEST

# %%
# predict_price_test = model.predict(x_test)
# predict_price_test = scala_y.inverse_transform(predict_price_test)
# y_test = scala_y.inverse_transform(y_test)

# %%
# validate = []
# for predict in predict_price_test:
#     predict= gradient.predict(np.array([predict]).reshape(-1,1))[0]
#     validate.append(predict)
# df_predict = pd.concat([pd.DataFrame(predict_price_test,columns=['predict_price_test'],index=None), pd.DataFrame(y_test,columns=['y_test'],index=None)], axis=1)
# df_predict['final_predict'] = df_predict['predict_price_test'] + validate
# print(df_predict.to_csv('result.csv'))
